# %%
import cv2
import pywt
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
first = cv2.imread('lena.jpg', 0)

# %%
first.shape
# Out:
# (1960, 1960)

# %%
plt.imshow(first, cmap = 'gray')

# %%
pywt.families()
# Out:
# ['haar',
#  'db',
#  'sym',
#  'coif',
#  'bior',
#  'rbio',
#  'dmey',
#  'gaus',
#  'mexh',
#  'morl',
#  'cgau',
#  'shan',
#  'fbsp',
#  'cmor']

# %%
c0=[[100, 50, 60, 150], [20 ,60, 40, 30],[50, 90 ,70, 82], [74, 66, 90, 58]]

# %%
import numpy as np
import pywt
import cv2    
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def w2d(img, mode='haar', level=4):
    imArray = cv2.imread(img)
    plt.imshow(imArray, cmap = 'gray')
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY)
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    
    
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)
    
    #plt.imshow(coeffs, cmap = 'gray')

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)
    #Display result
    plt.imshow(imArray_H, cmap = 'gray')

# %%
w2d("lena.jpg",'db1',10)

# %%
imArray = cv2.imread('lena.jpg')
plt.imshow(imArray, cmap = 'gray')
#Datatype conversions
#convert to grayscale
imArray = cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY)
#convert to float
imArray =  np.float32(imArray)   
imArray /= 255;

# %%
plt.imshow(imArray, cmap = 'gray')

# %%
# compute coefficients 
coeffs=pywt.wavedec2(imArray, 'haar', level=4)

# %%
coeffs
# Out:
# [array([[5.9921556, 5.9313717, 5.77549  , ..., 8.833332 , 4.4122543,
#          1.7117646],
#         [5.9762244, 5.88995  , 5.808823 , ..., 9.717647 , 7.630391 ,
#          3.6117644],
#         [5.9313717, 5.8926463, 5.8933816, ..., 9.267157 , 9.417646 ,
#          7.2931366],
#         ...,
#         [0.9132352, 1.3600488, 1.7473036, ..., 1.9595585, 2.6700976,
#          2.9676468],
#         [1.1142156, 1.3602939, 1.6892154, ..., 2.993382 , 3.5404406,
#          3.6607835],
#         [1.3245096, 1.3911762, 1.7671566, ..., 3.838235 , 4.1872544,
#          4.2794113]], dtype=float32),
#  (array([[-0.01813714, -0.00588218, -0.00294134, ..., -0.4318627 ,
#           -0.8558821 , -0.08235291],
#          [ 0.01544092,  0.02181369, -0.02303898, ..., -0.05588233,
#           -0.69313693, -0.97549015],
#          [ 0.00686218, -0.02499999, -0.02720545, ...,  0.18578398,
#           -0.24754936, -0.6960785 ],
#          ...,
# ...

# %%
plt.imshow(coeffs, cmap = 'gray')
